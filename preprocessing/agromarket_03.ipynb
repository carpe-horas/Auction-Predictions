# %%
import os
import pandas as pd

# 데이터 폴더 경로
folder_path = "../data/processed/agromarket_yearandseason/"

# 폴더 내 모든 파일 이름 가져오기
file_list = [os.path.join(folder_path, file) for file in os.listdir(folder_path) if file.endswith('.csv')]

# 데이터프레임 초기화
data_frames = []

# 모든 파일 읽어서 데이터프레임에 저장
for file in file_list:
    print(f"Loading {file}...")
    df = pd.read_csv(file)  
    data_frames.append(df)

# 데이터프레임 합치기
combined_df = pd.concat(data_frames, ignore_index=True)

# 데이터 크기 확인
print(f"Combined DataFrame shape: {combined_df.shape}")

# 데이터 타입 및 결측치 확인
print(combined_df.info())

# 데이터 샘플 확인
print(combined_df.head())
# Out:
# Loading ../data/processed/agromarket_yearandseason/agromarket_2019_Autumn.csv...
# Loading ../data/processed/agromarket_yearandseason/agromarket_2019_Spring.csv...
# Loading ../data/processed/agromarket_yearandseason/agromarket_2019_Summer.csv...
# Loading ../data/processed/agromarket_yearandseason/agromarket_2019_Winter.csv...
# Loading ../data/processed/agromarket_yearandseason/agromarket_2020_Autumn.csv...
# Loading ../data/processed/agromarket_yearandseason/agromarket_2020_Spring.csv...
# Loading ../data/processed/agromarket_yearandseason/agromarket_2020_Summer.csv...
# Loading ../data/processed/agromarket_yearandseason/agromarket_2020_Winter.csv...
# Loading ../data/processed/agromarket_yearandseason/agromarket_2021_Autumn.csv...
# Loading ../data/processed/agromarket_yearandseason/agromarket_2021_Spring.csv...
# Loading ../data/processed/agromarket_yearandseason/agromarket_2021_Summer.csv...
# Loading ../data/processed/agromarket_yearandseason/agromarket_2021_Winter.csv...
# Loading ../data/processed/agromarket_yearandseason/agromarket_2022_Autumn.csv...
# Loading ../data/processed/agromarket_yearandseason/agromarket_2022_Spring.csv...
# Loading ../data/processed/agromarket_yearandseason/agromarket_2022_Summer.csv...
# Loading ../data/processed/agromarket_yearandseason/agromarket_2022_Winter.csv...
# Loading ../data/processed/agromarket_yearandseason/agromarket_2023_Autumn.csv...
# Loading ../data/processed/agromarket_yearandseason/agromarket_2023_Spring.csv...
# Loading ../data/processed/agromarket_yearandseason/agromarket_2023_Summer.csv...
# Loading ../data/processed/agromarket_yearandseason/agromarket_2023_Winter.csv...
# Loading ../data/processed/agromarket_yearandseason/agromarket_2024_Autumn.csv...
# Loading ../data/processed/agromarket_yearandseason/agromarket_2024_Spring.csv...
# Loading ../data/processed/agromarket_yearandseason/agromarket_2024_Summer.csv...
# Loading ../data/processed/agromarket_yearandseason/agromarket_2024_Winter.csv...
# Combined DataFrame shape: (5643209, 15)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5643209 entries, 0 to 5643208
# Data columns (total 15 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   일자          object
#  1   연도          int64
#  2   월           int64
#  3   일           int64
#  4   계절          object
#  5   지역          object
#  6   도매시장        object
#  7   부류          object
#  8   품목          object
#  9   총물량(kg)     float64
#  10  총금액(원)      float64
#  11  총단가(원/kg)   float64
#  12  평균물량(kg)    float64
#  13  평균금액(원)     float64
#  14  평균단가(원/kg)  float64
# dtypes: float64(6), int64(3), object(6)
# memory usage: 645.8+ MB
# None
#            일자    연도  월  일  계절  지역 도매시장   부류   품목  총물량(kg)      총금액(원)  \
# 0  2019-09-02  2019  9  2  가을  강릉   강릉  과실류   감귤    650.0   2670000.0
# 1  2019-09-02  2019  9  2  가을  강릉   강릉  과실류   곶감     48.0    132000.0
# 2  2019-09-02  2019  9  2  가을  강릉   강릉  과실류  무화과     20.0     90000.0
# 3  2019-09-02  2019  9  2  가을  강릉   강릉  과실류  바나나   1404.0   2938000.0
# 4  2019-09-02  2019  9  2  가을  강릉   강릉  과실류    배  10657.5  34569400.0
#
#    총단가(원/kg)  평균물량(kg)      평균금액(원)  평균단가(원/kg)
# 0    4107.69     650.0   2670000.00     4107.69
# 1    2750.00      48.0    132000.00     2750.00
# 2    4500.00      20.0     90000.00     4500.00
# 3    2092.59     702.0   1469000.00     2092.59
# 4    3243.67    3552.5  11523133.33     3243.67

# %%
rows, columns = combined_df.shape
column_names = combined_df.columns.tolist()

(rows, columns, column_names)
# Out:
# (5643209,
#  15,
#  ['일자',
#   '연도',
#   '월',
#   '일',
#   '계절',
#   '지역',
#   '도매시장',
#   '부류',
#   '품목',
#   '총물량(kg)',
#   '총금액(원)',
#   '총단가(원/kg)',
#   '평균물량(kg)',
#   '평균금액(원)',
#   '평균단가(원/kg)'])

# %%
# 새로운 컬럼명
new_columns = [ 
    'date',            # 일자
    'year',            # 연도
    'month',           # 월
    'day',             # 일
    'season',          # 계절
    'region',          # 지역
    'wholesale_market', # 도매시장
    'category',        # 부류
    'item',            # 품목
    'quantity_kg',     # 총물량(kg)
    'price_won',       # 총금액(원)
    'unit_price_per_kg', # 총단가(원/kg)
    'avg_quantity_kg', # 평균물량(kg)
    'avg_price_won',   # 평균금액(원)
    'avg_unit_price_per_kg' # 평균단가(원/kg)
]

# %%
# 파일별 처리
for file in file_list:
    print(f"Processing {file}...")
    # 데이터 읽기
    df = pd.read_csv(file)
    
    # 컬럼명 변경
    df.columns = new_columns
    
    # 동일한 파일명으로 덮어쓰기 저장 (UTF-8-SIG 인코딩 설정)
    df.to_csv(file, index=False, encoding='utf-8-sig')
    print(f"{file}이 저장되었습니다.")

print("모든 파일 저장 완료")
# Out:
# Processing ../data/processed/agromarket_yearandseason/agromarket_2019_Autumn.csv...
# ../data/processed/agromarket_yearandseason/agromarket_2019_Autumn.csv이 저장되었습니다.
# Processing ../data/processed/agromarket_yearandseason/agromarket_2019_Spring.csv...
# ../data/processed/agromarket_yearandseason/agromarket_2019_Spring.csv이 저장되었습니다.
# Processing ../data/processed/agromarket_yearandseason/agromarket_2019_Summer.csv...
# ../data/processed/agromarket_yearandseason/agromarket_2019_Summer.csv이 저장되었습니다.
# Processing ../data/processed/agromarket_yearandseason/agromarket_2019_Winter.csv...
# ../data/processed/agromarket_yearandseason/agromarket_2019_Winter.csv이 저장되었습니다.
# Processing ../data/processed/agromarket_yearandseason/agromarket_2020_Autumn.csv...
# ../data/processed/agromarket_yearandseason/agromarket_2020_Autumn.csv이 저장되었습니다.
# Processing ../data/processed/agromarket_yearandseason/agromarket_2020_Spring.csv...
# ../data/processed/agromarket_yearandseason/agromarket_2020_Spring.csv이 저장되었습니다.
# Processing ../data/processed/agromarket_yearandseason/agromarket_2020_Summer.csv...
# ../data/processed/agromarket_yearandseason/agromarket_2020_Summer.csv이 저장되었습니다.
# Processing ../data/processed/agromarket_yearandseason/agromarket_2020_Winter.csv...
# ../data/processed/agromarket_yearandseason/agromarket_2020_Winter.csv이 저장되었습니다.
# Processing ../data/processed/agromarket_yearandseason/agromarket_2021_Autumn.csv...
# ../data/processed/agromarket_yearandseason/agromarket_2021_Autumn.csv이 저장되었습니다.
# Processing ../data/processed/agromarket_yearandseason/agromarket_2021_Spring.csv...
# ../data/processed/agromarket_yearandseason/agromarket_2021_Spring.csv이 저장되었습니다.
# Processing ../data/processed/agromarket_yearandseason/agromarket_2021_Summer.csv...
# ../data/processed/agromarket_yearandseason/agromarket_2021_Summer.csv이 저장되었습니다.
# Processing ../data/processed/agromarket_yearandseason/agromarket_2021_Winter.csv...
# ../data/processed/agromarket_yearandseason/agromarket_2021_Winter.csv이 저장되었습니다.
# Processing ../data/processed/agromarket_yearandseason/agromarket_2022_Autumn.csv...
# ../data/processed/agromarket_yearandseason/agromarket_2022_Autumn.csv이 저장되었습니다.
# Processing ../data/processed/agromarket_yearandseason/agromarket_2022_Spring.csv...
# ../data/processed/agromarket_yearandseason/agromarket_2022_Spring.csv이 저장되었습니다.
# Processing ../data/processed/agromarket_yearandseason/agromarket_2022_Summer.csv...
# ../data/processed/agromarket_yearandseason/agromarket_2022_Summer.csv이 저장되었습니다.
# Processing ../data/processed/agromarket_yearandseason/agromarket_2022_Winter.csv...
# ../data/processed/agromarket_yearandseason/agromarket_2022_Winter.csv이 저장되었습니다.
# Processing ../data/processed/agromarket_yearandseason/agromarket_2023_Autumn.csv...
# ../data/processed/agromarket_yearandseason/agromarket_2023_Autumn.csv이 저장되었습니다.
# Processing ../data/processed/agromarket_yearandseason/agromarket_2023_Spring.csv...
# ../data/processed/agromarket_yearandseason/agromarket_2023_Spring.csv이 저장되었습니다.
# Processing ../data/processed/agromarket_yearandseason/agromarket_2023_Summer.csv...
# ../data/processed/agromarket_yearandseason/agromarket_2023_Summer.csv이 저장되었습니다.
# Processing ../data/processed/agromarket_yearandseason/agromarket_2023_Winter.csv...
# ../data/processed/agromarket_yearandseason/agromarket_2023_Winter.csv이 저장되었습니다.
# Processing ../data/processed/agromarket_yearandseason/agromarket_2024_Autumn.csv...
# ../data/processed/agromarket_yearandseason/agromarket_2024_Autumn.csv이 저장되었습니다.
# Processing ../data/processed/agromarket_yearandseason/agromarket_2024_Spring.csv...
# ../data/processed/agromarket_yearandseason/agromarket_2024_Spring.csv이 저장되었습니다.
# Processing ../data/processed/agromarket_yearandseason/agromarket_2024_Summer.csv...
# ../data/processed/agromarket_yearandseason/agromarket_2024_Summer.csv이 저장되었습니다.
# Processing ../data/processed/agromarket_yearandseason/agromarket_2024_Winter.csv...
# ../data/processed/agromarket_yearandseason/agromarket_2024_Winter.csv이 저장되었습니다.
# 모든 파일 저장 완료
